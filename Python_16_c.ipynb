# %% [markdown]
# <a href="https://colab.research.google.com/github/Siraj-Ali8804/Scientific-Computing-/blob/main/Python_16_c.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Scope**
# A variable is only available from inside the region it is created. This is called scope.

# %% [markdown]
# **Local Scope**
# A variable created inside a function belongs to the local scope of that function, and can only be used inside that function.

# %%
def myfunc():
  x = 300
  print(x)

myfunc()
# Out:
# 300

# %%
def myfunc():
  x = 300
  def myinnerfunc():
    print(x)
  myinnerfunc()

myfunc()
# Out:
# 300

# %%
def myfunc_1():
  y=30
  x=y+4
  print(x)
myfunc_1()
# Out:
# 34

# %% [markdown]
# **Global Scope**
# A variable created in the main body of the Python code is a global variable and belongs to the global scope.
#
# Global variables are available from within any scope, global and local.

# %%
x = 300

def myfunc():
  print(x)

myfunc()

print(x)
# Out:
# 300
# 300

# %% [markdown]
# ## **Naming Variables**
# If you operate with the same variable name inside and outside of a function, Python will treat them as two separate variables, one available in the global scope (outside the function) and one available in the local scope (inside the function):

# %%
x = 300

def myfunc():
  x = 200
  print(x)

myfunc()

print(x)
# Out:
# 200
# 300

# %% [markdown]
# ## **Global Keyword**
# If you need to create a global variable, but are stuck in the local scope, you can use the global keyword.
#
# The global keyword makes the variable global.

# %%
def myfunc():
  global x
  x = 300

myfunc()

print(x)
# Out:
# 300

# %%
def myfunc_2():
  global x
  x= 33+33
myfunc_2()
print(x)
# Out:
# 66

# %% [markdown]
# **Nonlocal Keyword**
#
# The n**onlocal keyword** is used to work with variables inside nested functions.
#
# The nonlocal keyword makes the variable belong to the outer function

# %%
def myfunc1():
  x = "Jane"
  def myfunc2():
    nonlocal x
    x = "hello"
  myfunc2()
  return x

print(myfunc1())
# Out:
# hello

# %% [markdown]
# **The LEGB Rule**
#
# Python follows the LEGB rule when looking up variable names, and searches for them in this order:
#
# 1.   **Local** - Inside the current function
#
# 1.   **Enclosing** - Inside enclosing functions (from inner to outer)
# 2.   **Global** - At the top level of the module
#
#
# 2.   **Built-in** - In Python's built-in namespace

# %%
x = "global"

def outer():
  x = "enclosing"
  def inner():
    x = "local"
    print("Inner:", x)
  inner()
  print("Outer:", x)

outer()
print("Global:", x)
# Out:
# Inner: local
# Outer: enclosing
# Global: global

# %% [markdown]
# # **Decorators**
# Decorators let you add extra behavior to a function, without changing the function's code.
#
# A decorator is a function that takes another function as input and returns a new function.

# %%
def changecase(func):
  def myinner():
    return func().upper()
  return myinner

@changecase
def myfunction():
  return "Hello Sally"

print(myfunction())
# Out:
# HELLO SALLY

# %%
def changecase(func):
  def myinner():
    return func().upper()
  return myinner

@changecase
def myfunction():
  return "Hello Sally"

@changecase
def otherfunction():
  return "I am speed!"

print(myfunction())
print(otherfunction())
# Out:
# HELLO SALLY
# I AM SPEED!

# %%
def changecase(func):
  def myinner(x):
    return func(x).upper()
  return myinner

@changecase
def myfunction(nam):
  return "Hello " + nam

print(myfunction("John"))
# Out:
# HELLO JOHN
