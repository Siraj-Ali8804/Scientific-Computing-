# %% [markdown]
# <a href="https://colab.research.google.com/github/Siraj-Ali8804/Scientific-Computing-/blob/main/python_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Dictionary**
#
# Dictionaries are used to store data values in key:value pairs.
#
# A dictionary is a collection which is **ordered/unodered**,**changeable and do not allow duplicates**
#
# Dictionaries are written with **curly brackets, and have keys and values:**
#
# The values in dictionary items can be of any data type:

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}

# %%
dict_1= {"name":"uni", "jhon":"NU","michle":"Kansas","robert":"CIT"}
print(dict_1)
# Out:
# {'name': 'uni', 'jhon': 'NU', 'michle': 'Kansas', 'robert': 'CIT'}

# %%
thisdict = {
  "brand": "Ford",
  "electric": False,
  "year": 1964,
  "colors": ["red", "white", "blue"]
}
print(thisdict)
# Out:
# {'brand': 'Ford', 'electric': False, 'year': 1964, 'colors': ['red', 'white', 'blue']}

# %% [markdown]
# **Constructor**
# It is also possible to use the **dict()** constructor to make a dictionary.

# %%
set_1 = {"name":"uni", "jhon":"NU","michle":"Kansas","robert":"CIT"}
dict_2 = dict(set_1)
print(dict_2)
type(dict_2)
# Out:
# {'name': 'uni', 'jhon': 'NU', 'michle': 'Kansas', 'robert': 'CIT'}
# dict

# %% [markdown]
# **Accessing Items**
# You can access the items of a dictionary by referring to its key name, inside square brackets:

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
x = thisdict["model"]
print(x)
y= thisdict["year"]
print(y)
z= thisdict["brand"]
print(z)
# Out:
# Mustang
# 1964
# Ford

# %%
dict_1= {"name":"uni", "jhon":"NU","michle":"Kansas","robert":"CIT"}
q= dict_1["michle"]
print(q)
w= dict_1["robert"]
print(w)
t =dict_1["name"]
print(t)
# Out:
# Kansas
# CIT
# uni

# %% [markdown]
# There is also a method called **get()** that will give you the same result:

# %%
dict_2= {"azkia":"phys","ali":"english","adli":"grahics"}
x= dict_2.get("azkia")
print(x)
y= dict_2.get("ali")
print(y)
zz= dict_2.get("adil")
print(zz)
# Out:
# phys
# english
# None

# %% [markdown]
# **Get Keys**
#
# The **keys()** method will return a list of all the keys in the dictionary.

# %%
dict_3 = {"1":"siraj","2":"ahmed","3":"hussain"}
dict_3.keys()
# Out:
# dict_keys(['1', '2', '3'])

# %%
dict_2= {"azkia":"phys","ali":"english","adli":"grahics"}
dict_2.keys()
# Out:
# dict_keys(['azkia', 'ali', 'adli'])

# %% [markdown]
# **Change Values**
# You can change the value of a specific item by referring to its key name:

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
thisdict["year"] = 2018
thisdict["model"] = "BYD"
print(thisdict)
thisdict["brand"]= "Huwaei"
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'BYD', 'year': 2018}
# {'brand': 'Huwaei', 'model': 'BYD', 'year': 2018}

# %%
dict_3= {"azkia":"phys","ali":23,"adli":"grahics"}
dict_3["ali"] = "marketing"
print(dict_3)
dict_3["azkia"] ="optics"
print(dict_3)
# Out:
# {'azkia': 'phys', 'ali': 'marketing', 'adli': 'grahics'}
# {'azkia': 'optics', 'ali': 'marketing', 'adli': 'grahics'}

# %% [markdown]
# **Update Dictionary**
#
# The **update()** method will update the dictionary with the items from the given argument.
#
# The argument must be a dictionary, or an iterable object with key:value pairs.

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
thisdict.update({"year": 2020})
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 2020}

# %%
dict_4 ={'azkia': 'optics', 'ali': 'marketing', 'adli': 'grahics'}
dict_4.update({"azkia":"physics"})
print(dict_4)
# Out:
# {'azkia': 'physics', 'ali': 'marketing', 'adli': 'grahics'}

# %%
dict_4.update({"ali":"english"})
print(dict_4)
# Out:
# {'azkia': 'physics', 'ali': 'english', 'adli': 'grahics'}

# %% [markdown]
# **Removing Items**
#
# There are several methods to remove items from a dictionary:
#
# The pop() method removes the item with the specified key name:
#
# The popitem() method removes the last inserted item (in versions before 3.7, a random item is removed instead):
#
# The del keyword removes the item with the specified key name:
#
# The del keyword can also delete the dictionary completely:

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
thisdict.pop("model")
print(thisdict)
# Out:
# {'brand': 'Ford', 'year': 1964}

# %%
dict_4 ={'azkia': 'optics', 'ali': 'marketing', 'adli': 'grahics'}
dict_4.pop("azkia")
print(dict_4)
# Out:
# {'ali': 'marketing', 'adli': 'grahics'}

# %%
dict_4.pop("adli")
print(dict_4)
# Out:
# {'ali': 'marketing'}

# %%
dict_1= {"name":"uni", "jhon":"NU","michle":"Kansas","robert":"CIT"}
dict_1.popitem()
# Out:
# ('robert', 'CIT')

# %%
dict_1= {"name":"uni", "jhon":"NU","michle":"Kansas","robert":"CIT"}
del dict_1["name"]
print(dict_1)
del  dict_1["jhon"]
print(dict_1)
del dict_1["robert"]
print(dict_1)
del dict_1["michle"]
print(dict_1)
# Out:
# {'jhon': 'NU', 'michle': 'Kansas', 'robert': 'CIT'}
# {'michle': 'Kansas', 'robert': 'CIT'}
# {'michle': 'Kansas'}
# {}

# %%
dict_4 ={'azkia': 'optics', 'ali': 'marketing', 'adli': 'grahics'}
x= dict_4.clear()
print(x)
# Out:
# None

# %% [markdown]
# **copy**
#
# Make a copy of a dictionary with the **copy()** method:

# %%
dict_4 ={'azkia': 'optics', 'ali': 'marketing', 'adli': 'grahics'}
dict_5= dict_4.copy()
print(dict_5)
# Out:
# {'azkia': 'optics', 'ali': 'marketing', 'adli': 'grahics'}

# %% [markdown]
# **Nested Dictionaries**
#
# A dictionary can contain dictionaries, this is called nested dictionaries.

# %%
child1 = {
  "name" : "Emil",
  "year" : 2004
}
child2 = {
  "name" : "Tobias",
  "year" : 2007
}
child3 = {
  "name" : "Linus",
  "year" : 2011
}

myfamily = {
  "child1" : child1,
  "child2" : child2,
  "child3" : child3
}
print(myfamily)
print(myfamily["child2"]["name"])
# Out:
# {'child1': {'name': 'Emil', 'year': 2004}, 'child2': {'name': 'Tobias', 'year': 2007}, 'child3': {'name': 'Linus', 'year': 2011}}
# Tobias

# %%
sch= {"pervaiz":"5","javed":"7"}
coll= {"pervaiz":"11","javed":"12"}
uni= {"pervaiz":"13","javed":"14"}
flist= {"sch":sch,
        "coll":coll,
        "uni":uni}
print(flist)
# Out:
# {'sch': {'pervaiz': '5', 'javed': '7'}, 'coll': {'pervaiz': '11', 'javed': '12'}, 'uni': {'pervaiz': '13', 'javed': '14'}}

# %%
print(flist["sch"]["pervaiz"])
# Out:
# 5
