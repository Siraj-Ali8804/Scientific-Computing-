# %% [markdown]
# <a href="https://colab.research.google.com/github/Siraj-Ali8804/Scientific-Computing-/blob/main/Python_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Python Conditions**
#
# Python supports the usual logical conditions from mathematics:
#
# *   Equals: a == b
#
# *   Not Equals: a != b
#
# *   Less than: a < b
# *   Less than or equal to: a <= b
#
#
# *   Greater than: a > b
#
#
# *   Greater than or equal to: a >= b

# %% [markdown]
# ## if statement
# An "if statement" is written by using the if keyword.
#
# if statement evaluates a condition (an expression that results in True or False)

# %%
a= 10
if a ==10 :
  print(" a is equal to ten")
# Out:
#  a is equal to ten

# %%
s= 100
if s> 12:
  print(" s is grater then telve")
# Out:
#  s is grater then telve

# %% [markdown]
# **Multiple Statements in If Block**
# You can have multiple statements inside an if block. All statements must be indented at the same level.

# %%
age = 20
if age >= 18:
  print("you can vote" )
  print(" you are allowed to vote")
# Out:
# you can vote
#  you are allowed to vote

# %% [markdown]
# **Using Variables in Conditions**
# Boolean variables can be used directly in if statements without comparison operators.

# %%
is_logged_in = True
if is_logged_in:
  print("Welcome back!")
# Out:
# Welcome back!

# %%
is_logged_in = True
if is_logged_in:
  print("retype password")
# Out:
# retype password

# %% [markdown]
# ## Elif Statement
# The Elif Keyword
# The **elif** keyword is Python's way of saying "if the previous conditions were not true, then try this condition".
#
# The elif keyword allows you to check multiple expressions for True and execute a block of code as soon as one of the conditions evaluates to True.
#
# **When to Use Elif**
# Use elif when you have multiple mutually exclusive conditions to check. This is more efficient than using multiple separate if statements because Python stops checking once it finds a true condition.

# %%
a= 20
b= 30
if a == 40:
  print("your age is 20")
elif a<b:
  print("your age is 30")
# Out:
# your age is 30

# %%
a = 33
b = 33
if b > a:
  print("b is greater than a")
elif a == b:
  print("a and b are equal")
# Out:
# a and b are equal

# %%
q= 34
w = 36
if q>w:
  print("greater")
elif q<w:
  print("not")
# Out:
# not

# %%
score = 90


if score >= 90:
  print("Grade: A")
elif score >= 80:
  print("Grade: B")
elif score >= 70:
  print("Grade: C")
elif score >= 60:
  print("Grade: D")
# Out:
# Grade: A

# %% [markdown]
# ## Else Statement
# Else Keyword
#
# The else keyword catches anything which isn't caught by the preceding conditions.
#
# The else statement is executed when the if condition (and any elif conditions) evaluate to False
#
# The else statement acts as a fallback that executes when none of the preceding conditions are true. This makes it useful for error handling, validation, and providing default values.

# %%
a= 23
b= 33
if a==b:
  print("a is equal to b")
elif a>b:
  print("a is greater then b")
else:
  print("a is less then b")
# Out:
# a is less then b

# %%
temperature = 50

if temperature > 30:
  print("It's hot outside!")
elif temperature > 20:
  print("It's warm outside")
elif temperature > 10:
  print("It's cool outside")
else:
  print("It's cold outside!")
# Out:
# It's hot outside!

# %%
tem= 0
if tem > 30:
  print("hot outside")
elif tem > 20:
  print("normal outside")
elif tem > 10:
  print(" tem of tea")
else:
  print("cold outside")
# Out:
# cold outside

# %%
marks= 60
if marks < 40:
  print("YOU ARE FAIL")
elif marks>= 40:
  print(" you are pass")
# Out:
#  you are pass

# %% [markdown]
# ## Logical Operators
#
# Logical operators are used to combine conditional statements. Python has three logical operators:
#
# **and** - Returns True if both statements are true
#
# **or** - Returns True if one of the statements is true
#
# **not** - Reverses the result, returns False if the result is true

# %%
a = 200
b = 33
c = 500
if a > b and c > a:
  print("Both conditions are True")
# Out:
# Both conditions are True

# %%
o= 00
i= 200
p= 500
if  o>i and i<p:
  print(" and will give true result")
else:
  print(" WTF")
# Out:
#  WTF

# %%
o= 33
i=99
p= 445
if o>1 or i<p:
  print("look one of two condition is correct it will print")
else:
  print("WTF")
# Out:
# look one of two condition is correct it will print

# %%
from __future__ import print_function
a= 5
b = 4
if not b>a:
  print(" look not key word revserd the true in false")
else:
  print("wtf")
# Out:
#  look not key word revserd the true in false

# %%
username = "Tobias"
password = "secre123"
is_verified = True

if username and password and is_verified:
  print("Login successful")
else:
  print("Login failed")
# Out:
# Login successful

# %% [markdown]
# ## Nested If Statements
# You can have if statements inside if statements. This is called nested if statements.

# %%
age = 25
has_license = True

if age >= 18:
  if has_license:
    print("You can drive")
  else:
    print("You need a license")
else:
  print("You are too young to drive")
# Out:
# You can drive

# %%
age = 18
cnic =True

if age>=18:
  if cnic:
    print("you can vote")
  else:
     print("you need cnic")
else:
  print("you can not vote")
# Out:
# you can vote

# %%
age = 18
cnic = True
if age >= 18:
  if cnic:
    print("you can vote")
  else:
      print("you need cnic")
else:
  print("you can not vote")
# Out:
# you can vote

# %%
age = 18
cnic = False

if age >= 18:
    if cnic:
        print("you can vote")
    else:
        print("you need cnic")
else:
    print("you can not vote")
# Out:
# you need cnic

# %%
age= 7
mental_health= True

if age>= 7:
  if mental_health:
    print("give him addmission")
  else:
    print("need health certificate")
else:
  print("you can not give addmission")
# Out:
# give him addmission

# %% [markdown]
# ## Multiple Levels of Nesting
# You can nest as many levels deep as needed,

# %%
score = 85
attendance = 90
submitted = True

if score >= 60:
  if attendance >= 80:
    if submitted:
      print("Pass with good standing")
    else:
      print("Pass but missing assignment")
  else:
    print("Pass but low attendance")
else:
  print("Fail")
# Out:
# Pass with good standing

# %%
marks= 94
attendance = 90
assingmnets_submitted= True

if marks>= 90:
  if attendance >=90:
    if assingmnets_submitted:
      print("well done")
  else:
    print("pass but attentdence is short")
else:
    print("pass")
else:
  print("fail")
# Out:
# fail

# %%
marks = 94
attendance = 90  # Corrected to an assignment
assingmnets_submitted = True

if marks >= 90:  # Adjusted threshold to include 94
    if attendance >= 90:
        if assingmnets_submitted:
            print("well done")
        else:
            print("pass but attendance is short") # Logic correction: assignment missing
    else:
        print("pass but attendance is low")
else:
    print("fail")
# Out:
# well done

# %%
marks= 94
attendance = 90
assingmnets_submitted= True

if marks >= 90:
  if attendance >= 90:
    if assingmnets_submitted:
      print("well done")
  else:
    print("pass but attentdence is short")
else:
    print("pass")
# Out:
# well done

# %%
marks = 94
attendance = 90
assingmnets_submitted = True

if marks >= 90:
    if attendance >= 90:
        if assingmnets_submitted:
            print("well done")
        else:
            print("pass but assignments missing") # Fixed logic
    else:
        print("pass but attendance is short") # Moved this else here
else:
    print("fail")
# Out:
# well done

# %% [markdown]
# ###pass Statement
# if statements cannot be empty, but if you for some reason have an if statement with no content, put in the pass statement to avoid getting an error.

# %%
a = 33
b = 200

if b > a:
  pass

# %% [markdown]
# **The pass statement is useful in several situations:**
#
# When you're creating code structure but haven't implemented the logic yet
#
# When a statement is required syntactically but no action is needed
# As a placeholder for future code during development
#
# In empty functions or classes that you plan to implement later

# %%
age = 16

if age < 18:
  pass # TODO: Add underage logic later
else:
  print("Access granted")
