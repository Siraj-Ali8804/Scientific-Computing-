# %% [markdown]
# <a href="https://colab.research.google.com/github/Siraj-Ali8804/Scientific-Computing-/blob/main/Python_15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Loops
# oops are control flow statements used to repeatedly execute a block of code to automate repetitive tasks.
#
# Python has two primitive loop commands:
#
# **while** loops and
# **for** loops

# %% [markdown]
# **For Loops**
#
# A for loop is used for iterating over a sequence (that is either a list, a tuple, a dictionary, a set, or a string
#
# With the for loop we can execute a set of statements, once for each item in a list, tuple, set etc.
#
# The for loop does not require an indexing variable to set beforehand.

# %%
fruits = ["apple", "banana", "cherry"]
for x in fruits:
  print(x)
# Out:
# apple
# banana
# cherry

# %%
fruits = ["apple", "banana", "cherry"]
print(fruits)
# Out:
# ['apple', 'banana', 'cherry']

# %%
friends= ["ali","jhon","ihsan","azkia"]
for x in friends:
  print(x)
# Out:
# ali
# jhon
# ihsan
# azkia

# %%
class_b =["daneil","assyljan","zahnaby","nutughan","azkia","arghnan"]
for x in class_b:
  print(x)
# Out:
# daneil
# assyljan
# zahnaby
# nutughan
# azkia
# arghnan

# %%
class_g= ["kamila","karakakt","sabina","aruzhan","adel","sumera"]
for x in class_g:
  print(x)
# Out:
# kamila
# karakakt
# sabina
# aruzhan
# adel
# sumera

# %% [markdown]
# **The break Statement**
#
# With the break statement we can stop the loop before it has looped through all the items:

# %%
from __future__ import barry_as_FLUFL
class_b =["daneil","assyljan","zahnaby","nutughan","azkia","arghnan"]
for x in class_b:
  print (x)
  if x == "azkia":
    break
  print(x)
# Out:
# daneil
# daneil
# assyljan
# assyljan
# zahnaby
# zahnaby
# nutughan
# nutughan
# azkia

# %%
class_g= ["kamila","karakakt","sabina","aruzhan","adel","sumera"]
for x in class_g:
  print(x)
  if x== "sabina":
    break
# Out:
# kamila
# karakakt
# sabina

# %% [markdown]
# **continue Statement**
#
# With the **continue** statement we can stop the current iteration of the loop, and continue with the next:

# %%
fruits = ["apple", "banana", "cherry"]
for x in fruits:
  if x == "banana":
    continue
  print(x)
# Out:
# apple
# cherry

# %%
class_b =["daneil","assyljan","zahnaby","nutughan","azkia","arghnan"]
for x in class_b:
  if x== "azkia":
    continue
  print(x)
# Out:
# daneil
# assyljan
# zahnaby
# nutughan
# arghnan

# %%
class_g= ["kamila","karakakt","sabina","aruzhan","adel","sumera"]
for x in class_g:
  if x == "sumera":
    continue
  print(x)
# Out:
# kamila
# karakakt
# sabina
# aruzhan
# adel

# %%
class_g= ["kamila","karakakt","sabina","aruzhan","adel","sumera"]
for x in class_g:
    if x in ["aruzhan","adel","sumera"]:
      continue
    print(x)
# Out:
# kamila
# karakakt
# sabina

# %% [markdown]
# # The range() Function
# To loop through a set of code a specified number of times, we can use the **range()** function,
#
# The **range()** function returns a sequence of numbers, starting from 0 by default, and increments by 1 (by default), and ends at a specified number.

# %%
for i in range(6):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# The **range()** function defaults to **0** as a starting value, however it is possible to specify the starting value by adding a parameter: **range(2, 6)**, which means values from **2 to 6 (but not including 6)**:

# %%
for  i in range(2,8):
  print(i)
# Out:
# 2
# 3
# 4
# 5
# 6
# 7

# %%
for i in range(2,20,4):
  print(i)
# Out:
# 2
# 6
# 10
# 14
# 18

# %%
for i in range(3,20,3):
  print(i)
# Out:
# 3
# 6
# 9
# 12
# 15
# 18

# %% [markdown]
# **Else in For Loop**
#
# The **else** keyword in a for loop specifies a block of code to be executed when the loop is finished:

# %%
for x in range(6):
  print(x)
else:
  print("Finally finished!")
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# Finally finished!

# %%
for i in range(2,10,2):
  print(i)
else:
  print("it copy")
# Out:
# 2
# 4
# 6
# 8
# it copy

# %% [markdown]
# ## Nested Loops
# A nested loop is a loop inside a loop.
#
# The "inner loop" will be executed one time for each iteration of the "outer loop":

# %%
adj = ["red", "big", "tasty"]
fruits = ["apple", "banana", "cherry"]

for x in adj:
  for y in fruits:
    print(x, y)
# Out:
# red apple
# red banana
# red cherry
# big apple
# big banana
# big cherry
# tasty apple
# tasty banana
# tasty cherry

# %%
num = [1,2,3]
alpha = ["a","b"]
for x in num:
  for y in alpha:
    print(x,y)
# Out:
# 1 a
# 1 b
# 2 a
# 2 b
# 3 a
# 3 b

# %%
mcqs =["newon","pascal","kelvin"]
num = [1,2,3]
for i in mcqs:
  for x in num:
    print(x,i)
# Out:
# 1 newon
# 2 newon
# 3 newon
# 1 pascal
# 2 pascal
# 3 pascal
# 1 kelvin
# 2 kelvin
# 3 kelvin

# %%
students = ["Ali", "Sara"]
subjects = ["Math", "Physics"]

for s in students:
    for sub in subjects:
        print(s, "studies", sub)
# Out:
# Ali studies Math
# Ali studies Physics
# Sara studies Math
# Sara studies Physics

# %%
count = 0
for x in ["a", "b"]:
    for y in [1, 2, 3]:
        count += 1

print(count)
# Out:
# 6
